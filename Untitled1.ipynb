# %% [markdown]
# <a href="https://colab.research.google.com/github/xavierGIT04/IA/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy scipy matplotlib ipython pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.1 MB/s eta 0:00:00
# ...

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import numpy as np


iris_dataset = load_iris()
X_train, X_test, y_train, y_test = train_test_split(
    iris_dataset['data'], iris_dataset['target'], random_state=0
)

knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)

X_new = np.array([[5, 2.9, 1, 0.2]])


"""prediction = knn.predict(X_new) #prediction est l'indice de la classe correspondante dans le tableau target_names
print(f"prediction : {prediction}")
print(f"classe predite : {iris_dataset['target_names'][prediction]}")"""

"""verifier le score 1ere manière
y_predict = knn.predict(X_test)
print(y_predict)
print(y_test)
print(np.mean(y_test == y_predict))
"""
"""deuxième manière de verifier le score de bonne prediction
print(f"{knn.score(X_test, y_test):.2f}")"""
# Out:
# 0.97
